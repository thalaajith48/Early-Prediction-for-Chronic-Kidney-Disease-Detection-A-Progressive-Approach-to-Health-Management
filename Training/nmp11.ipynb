# %%
#import libraries
import warnings
import pandas as  pd
import numpy as np
from collections import Counter as c
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import tensorflow
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pickle
warnings.filterwarnings('ignore')
import math

# %%
#importing a dataset

data = pd.read_csv('/content/kidney_disease (1).csv')

# %%
data
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
#  17  wc              295 non-null    object
#  18  rc              270 non-null    object
#  19  htn             398 non-null    object
#  20  dm              398 non-null    object
#  21  cad             398 non-null    object
#  22  appet           399 non-null    object
#  23  pe              399 non-null    object
#  24  ane             399 non-null    object
#  25  classification  400 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.4+ KB

# %%
#renaming the column

data.columns=['id','age','blood_pressure','specific_gravity','albumin','sugar',
              'red_blood_cells','pus_cell','pus_cell_clumps','bacteria','blood gulcose random',
              'blood_urea','serum_creatinine','sodium','potassium','hemoglobin','packed_cell_volume'
              ,'white_blood_cell_count','red_blood_cell_count','hypertension',
              'diabetesmellitus','coronary_artery_disease','appetite','pedal_edema',
              'anemia','class']

# %%
data.head(10)
# Out:
#    id   age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0   0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   1   7.0            50.0             1.020      4.0    0.0             NaN
# 2   2  62.0            80.0             1.010      2.0    3.0          normal
# 3   3  48.0            70.0             1.005      4.0    0.0          normal
# 4   4  51.0            80.0             1.010      2.0    0.0          normal
# 5   5  60.0            90.0             1.015      3.0    0.0             NaN
# 6   6  68.0            70.0             1.010      0.0    0.0             NaN
# 7   7  24.0             NaN             1.015      2.0    4.0          normal
# 8   8  52.0           100.0             1.015      3.0    0.0          normal
# 9   9  53.0            90.0             1.020      2.0    0.0        abnormal
#
#    pus_cell pus_cell_clumps    bacteria  ...  packed_cell_volume  \
# 0    normal      notpresent  notpresent  ...                  44
# 1    normal      notpresent  notpresent  ...                  38
# 2    normal      notpresent  notpresent  ...                  31
# 3  abnormal         present  notpresent  ...                  32
# 4    normal      notpresent  notpresent  ...                  35
# 5       NaN      notpresent  notpresent  ...                  39
# 6    normal      notpresent  notpresent  ...                  36
# 7  abnormal      notpresent  notpresent  ...                  44
# 8  abnormal         present  notpresent  ...                  33
# 9  abnormal         present  notpresent  ...                  29
#
#    white_blood_cell_count  red_blood_cell_count  hypertension  \
# 0                    7800                   5.2           yes
# 1                    6000                   NaN            no
# 2                    7500                   NaN            no
# 3                    6700                   3.9           yes
# 4                    7300                   4.6            no
# 5                    7800                   4.4           yes
# 6                     NaN                   NaN            no
# 7                    6900                     5            no
# 8                    9600                   4.0           yes
# 9                   12100                   3.7           yes
#
#    diabetesmellitus  coronary_artery_disease appetite pedal_edema anemia class
# 0               yes                       no     good          no     no   ckd
# 1                no                       no     good          no     no   ckd
# 2               yes                       no     poor          no    yes   ckd
# 3                no                       no     poor         yes    yes   ckd
# 4                no                       no     good          no     no   ckd
# 5               yes                       no     good         yes     no   ckd
# 6                no                       no     good          no     no   ckd
# 7               yes                       no     good         yes     no   ckd
# 8               yes                       no     good          no    yes   ckd
# 9               yes                       no     poor          no    yes   ckd
#
# [10 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       400 non-null    int64
#  1   age                      391 non-null    float64
#  2   blood_pressure           388 non-null    float64
#  3   specific_gravity         353 non-null    float64
#  4   albumin                  354 non-null    float64
#  5   sugar                    351 non-null    float64
#  6   red_blood_cells          248 non-null    object
#  7   pus_cell                 335 non-null    object
#  8   pus_cell_clumps          396 non-null    object
#  9   bacteria                 396 non-null    object
#  10  blood gulcose random     356 non-null    float64
#  11  blood_urea               381 non-null    float64
#  12  serum_creatinine         383 non-null    float64
#  13  sodium                   313 non-null    float64
#  14  potassium                312 non-null    float64
#  15  hemoglobin               348 non-null    float64
#  16  packed_cell_volume       330 non-null    object
#  17  white_blood_cell_count   295 non-null    object
#  18  red_blood_cell_count     270 non-null    object
#  19  hypertension             398 non-null    object
#  20  diabetesmellitus         398 non-null    object
#  21  coronary_artery_disease  398 non-null    object
#  22  appetite                 399 non-null    object
#  23  pedal_edema              399 non-null    object
#  24  anemia                   399 non-null    object
#  25  class                    400 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.4+ KB

# %%
data.isnull().any()
# Out:
# id                         False
# age                         True
# blood_pressure              True
# specific_gravity            True
# albumin                     True
# sugar                       True
# red_blood_cells             True
# pus_cell                    True
# pus_cell_clumps             True
# bacteria                    True
# blood gulcose random        True
# blood_urea                  True
# serum_creatinine            True
# sodium                      True
# potassium                   True
# hemoglobin                  True
# packed_cell_volume          True
# white_blood_cell_count      True
# red_blood_cell_count        True
# hypertension                True
# diabetesmellitus            True
# coronary_artery_disease     True
# appetite                    True
# pedal_edema                 True
# anemia                      True
# class                      False
# dtype: bool

# %%
data.drop('id',axis=1,inplace=True)

# %%
data.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#    pus_cell pus_cell_clumps    bacteria  blood gulcose random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                  44                    7800                   5.2
# 1                  38                    6000                   NaN
# 2                  31                    7500                   NaN
# 3                  32                    6700                   3.9
# 4                  35                    7300                   4.6
#
#    hypertension  diabetesmellitus coronary_artery_disease appetite  \
# 0           yes               yes                      no     good
# 1            no                no                      no     good
# 2            no               yes                      no     poor
# 3           yes                no                      no     poor
# 4            no                no                      no     good
#
#   pedal_edema anemia class
# 0          no     no   ckd
# 1          no     no   ckd
# 2          no    yes   ckd
# 3         yes    yes   ckd
# 4          no     no   ckd
#
# [5 rows x 25 columns]

# %%
data.isnull().any()
# Out:
# age                         True
# blood_pressure              True
# specific_gravity            True
# albumin                     True
# sugar                       True
# red_blood_cells             True
# pus_cell                    True
# pus_cell_clumps             True
# bacteria                    True
# blood gulcose random        True
# blood_urea                  True
# serum_creatinine            True
# sodium                      True
# potassium                   True
# hemoglobin                  True
# packed_cell_volume          True
# white_blood_cell_count      True
# red_blood_cell_count        True
# hypertension                True
# diabetesmellitus            True
# coronary_artery_disease     True
# appetite                    True
# pedal_edema                 True
# anemia                      True
# class                      False
# dtype: bool

# %%
#Handling missing values

# %%
data['blood gulcose random'].fillna(data['blood gulcose random'].mean(),inplace=True)

# %%
data['blood gulcose random'].head(25)
# Out:
# 0     121.000000
# 1     148.036517
# 2     423.000000
# 3     117.000000
# 4     106.000000
# 5      74.000000
# 6     100.000000
# 7     410.000000
# 8     138.000000
# 9      70.000000
# 10    490.000000
# 11    380.000000
# 12    208.000000
# 13     98.000000
# 14    157.000000
# 15     76.000000
# 16     99.000000
# 17    114.000000
# 18    263.000000
# 19    100.000000
# 20    173.000000
# 21    148.036517
# 22     95.000000
# 23    148.036517
# 24    148.036517
# Name: blood gulcose random, dtype: float64

# %%
data['blood_pressure'].fillna(data['blood_pressure'].mean(),inplace=True)

# %%
data['blood_urea'].fillna(data['blood_urea'].mean(),inplace=True)

# %%
data['hemoglobin'].fillna(data['hemoglobin'].mean(),inplace=True)

# %%
data['packed_cell_volume']  = pd.to_numeric(data['packed_cell_volume'],errors='coerce')

# %%
data['packed_cell_volume'].fillna(data['packed_cell_volume'].mean(),inplace=True)

# %%
data['potassium'].fillna(data['potassium'].mean(),inplace=True)

# %% [markdown]
# Converting object into float

# %%
data['red_blood_cell_count'] = pd.to_numeric(data['red_blood_cell_count'], errors='coerce')

# %%
data['red_blood_cell_count'].fillna(data['red_blood_cell_count'].mean(),inplace=True)

# %%
data['serum_creatinine'] = pd.to_numeric(data['serum_creatinine'], errors='coerce')

# %%
data['serum_creatinine'].fillna(data['serum_creatinine'].mean(),inplace=True)

# %%
data['sodium'].fillna(data['sodium'].mean(),inplace=True)

# %%
data['white_blood_cell_count'] = pd.to_numeric(data['white_blood_cell_count'], errors = 'coerce')

# %%
data['white_blood_cell_count'].fillna(data['white_blood_cell_count'].mean(),inplace=True)

# %%
data['age'].fillna(data['age'].mode()[0],inplace=True)

# %%
data['hypertension'].fillna(data['hypertension'].mode()[0],inplace=True)

# %%
data['pus_cell_clumps'].fillna(data['pus_cell_clumps'].mode()[0],inplace=True)

# %%
data['appetite'].fillna(data['appetite'].mode()[0],inplace=True)

# %%
data['albumin'].fillna(data['albumin'].mode()[0],inplace=True)

# %%
data['pus_cell'].fillna(data['pus_cell'].mode()[0],inplace=True)

# %%
data['red_blood_cells'].fillna(data['red_blood_cells'].mode()[0],inplace=True)

# %%
data['coronary_artery_disease'].fillna(data['coronary_artery_disease'].mode()[0],inplace=True)

# %%
data['bacteria'].fillna(data['bacteria'].mode()[0],inplace=True)

# %%
data['anemia'].fillna(data['anemia'].mode()[0],inplace=True)

# %%
data['sugar'].fillna(data['sugar'].mode()[0],inplace=True)

# %%
data['diabetesmellitus'].fillna(data['diabetesmellitus'].mode()[0],inplace=True)

# %%
data['pedal_edema'].fillna(data['pedal_edema'].mode()[0],inplace=True)

# %%
data['specific_gravity'].fillna(data['specific_gravity'].mode()[0],inplace=True)

# %%
data.head(25)
# Out:
#      age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0   48.0       80.000000             1.020      1.0    0.0          normal
# 1    7.0       50.000000             1.020      4.0    0.0          normal
# 2   62.0       80.000000             1.010      2.0    3.0          normal
# 3   48.0       70.000000             1.005      4.0    0.0          normal
# 4   51.0       80.000000             1.010      2.0    0.0          normal
# 5   60.0       90.000000             1.015      3.0    0.0          normal
# 6   68.0       70.000000             1.010      0.0    0.0          normal
# 7   24.0       76.469072             1.015      2.0    4.0          normal
# 8   52.0      100.000000             1.015      3.0    0.0          normal
# 9   53.0       90.000000             1.020      2.0    0.0        abnormal
# 10  50.0       60.000000             1.010      2.0    4.0          normal
# 11  63.0       70.000000             1.010      3.0    0.0        abnormal
# 12  68.0       70.000000             1.015      3.0    1.0          normal
# 13  68.0       70.000000             1.020      0.0    0.0          normal
# 14  68.0       80.000000             1.010      3.0    2.0          normal
# 15  40.0       80.000000             1.015      3.0    0.0          normal
# 16  47.0       70.000000             1.015      2.0    0.0          normal
# 17  47.0       80.000000             1.020      0.0    0.0          normal
# 18  60.0      100.000000             1.025      0.0    3.0          normal
# 19  62.0       60.000000             1.015      1.0    0.0          normal
# 20  61.0       80.000000             1.015      2.0    0.0        abnormal
# 21  60.0       90.000000             1.020      0.0    0.0          normal
# 22  48.0       80.000000             1.025      4.0    0.0          normal
# 23  21.0       70.000000             1.010      0.0    0.0          normal
# 24  42.0      100.000000             1.015      4.0    0.0          normal
#
#     pus_cell pus_cell_clumps    bacteria  blood gulcose random  ...  \
# 0     normal      notpresent  notpresent            121.000000  ...
# 1     normal      notpresent  notpresent            148.036517  ...
# 2     normal      notpresent  notpresent            423.000000  ...
# 3   abnormal         present  notpresent            117.000000  ...
# 4     normal      notpresent  notpresent            106.000000  ...
# 5     normal      notpresent  notpresent             74.000000  ...
# 6     normal      notpresent  notpresent            100.000000  ...
# 7   abnormal      notpresent  notpresent            410.000000  ...
# 8   abnormal         present  notpresent            138.000000  ...
# 9   abnormal         present  notpresent             70.000000  ...
# 10  abnormal         present  notpresent            490.000000  ...
# 11  abnormal         present  notpresent            380.000000  ...
# 12    normal         present  notpresent            208.000000  ...
# 13    normal      notpresent  notpresent             98.000000  ...
# 14  abnormal         present     present            157.000000  ...
# 15    normal      notpresent  notpresent             76.000000  ...
# 16    normal      notpresent  notpresent             99.000000  ...
# 17    normal      notpresent  notpresent            114.000000  ...
# 18    normal      notpresent  notpresent            263.000000  ...
# 19  abnormal         present  notpresent            100.000000  ...
# 20  abnormal      notpresent  notpresent            173.000000  ...
# 21    normal      notpresent  notpresent            148.036517  ...
# 22  abnormal      notpresent  notpresent             95.000000  ...
# 23    normal      notpresent  notpresent            148.036517  ...
# 24  abnormal      notpresent     present            148.036517  ...
#
#     packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0            44.000000             7800.000000              5.200000
# 1            38.000000             6000.000000              4.707435
# 2            31.000000             7500.000000              4.707435
# 3            32.000000             6700.000000              3.900000
# 4            35.000000             7300.000000              4.600000
# 5            39.000000             7800.000000              4.400000
# 6            36.000000             8406.122449              4.707435
# 7            44.000000             6900.000000              5.000000
# 8            33.000000             9600.000000              4.000000
# 9            29.000000            12100.000000              3.700000
# 10           28.000000             8406.122449              4.707435
# 11           32.000000             4500.000000              3.800000
# 12           28.000000            12200.000000              3.400000
# 13           38.884498             8406.122449              4.707435
# 14           16.000000            11000.000000              2.600000
# 15           24.000000             3800.000000              2.800000
# 16           38.884498             8406.122449              4.707435
# 17           38.884498             8406.122449              4.707435
# 18           37.000000            11400.000000              4.300000
# 19           30.000000             5300.000000              3.700000
# 20           24.000000             9200.000000              3.200000
# 21           32.000000             6200.000000              3.600000
# 22           32.000000             6900.000000              3.400000
# 23           38.884498             8406.122449              4.707435
# 24           39.000000             8300.000000              4.600000
#
#     hypertension  diabetesmellitus  coronary_artery_disease  appetite  \
# 0            yes               yes                       no      good
# 1             no                no                       no      good
# 2             no               yes                       no      poor
# 3            yes                no                       no      poor
# 4             no                no                       no      good
# 5            yes               yes                       no      good
# 6             no                no                       no      good
# 7             no               yes                       no      good
# 8            yes               yes                       no      good
# 9            yes               yes                       no      poor
# 10           yes               yes                       no      good
# 11           yes               yes                       no      poor
# 12           yes               yes                      yes      poor
# 13           yes               yes                      yes      poor
# 14           yes               yes                      yes      poor
# 15           yes                no                       no      good
# 16            no                no                       no      good
# 17           yes                no                       no      poor
# 18           yes               yes                      yes      good
# 19           yes                no                      yes      good
# 20           yes               yes                      yes      poor
# 21           yes               yes                      yes      good
# 22           yes                no                       no      good
# 23            no                no                       no      poor
# 24           yes                no                       no      poor
#
#     pedal_edema anemia class
# 0            no     no   ckd
# 1            no     no   ckd
# 2            no    yes   ckd
# 3           yes    yes   ckd
# 4            no     no   ckd
# 5           yes     no   ckd
# 6            no     no   ckd
# 7           yes     no   ckd
# 8            no    yes   ckd
# 9            no    yes   ckd
# 10           no    yes   ckd
# 11          yes     no   ckd
# 12          yes     no   ckd
# 13          yes     no   ckd
# 14          yes     no   ckd
# 15           no    yes   ckd
# 16           no     no   ckd
# 17           no     no   ckd
# 18           no     no   ckd
# 19           no     no   ckd
# 20          yes    yes   ckd
# 21           no     no   ckd
# 22           no    yes   ckd
# 23           no    yes   ckd
# 24           no     no   ckd
#
# [25 rows x 25 columns]

# %% [markdown]
# Checking the null values

# %%
data.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood gulcose random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# hemoglobin                 float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetesmellitus            object
# coronary_artery_disease     object
# appetite                    object
# pedal_edema                 object
# anemia                      object
# class                       object
# dtype: object

# %%
data.isnull().sum()
# Out:
# age                        0
# blood_pressure             0
# specific_gravity           0
# albumin                    0
# sugar                      0
# red_blood_cells            0
# pus_cell                   0
# pus_cell_clumps            0
# bacteria                   0
# blood gulcose random       0
# blood_urea                 0
# serum_creatinine           0
# sodium                     0
# potassium                  0
# hemoglobin                 0
# packed_cell_volume         0
# white_blood_cell_count     0
# red_blood_cell_count       0
# hypertension               0
# diabetesmellitus           0
# coronary_artery_disease    0
# appetite                   0
# pedal_edema                0
# anemia                     0
# class                      0
# dtype: int64

# %% [markdown]
# handling categorical values

# %%
catcols=set(data.dtypes [data.dtypes== 'O'].index.values)
print(catcols)
# Out:
# {'appetite', 'diabetesmellitus', 'class', 'pus_cell_clumps', 'anemia', 'coronary_artery_disease', 'pus_cell', 'pedal_edema', 'hypertension', 'bacteria', 'red_blood_cells'}

# %%
catcols
# Out:
# {'anemia',
#  'appetite',
#  'bacteria',
#  'class',
#  'coronary_artery_disease',
#  'diabetesmellitus',
#  'hypertension',
#  'pedal_edema',
#  'pus_cell',
#  'pus_cell_clumps',
#  'red_blood_cells'}

# %%
for i in catcols:
  print("columns:",i)
  print(c(data[i]))
  print('*'*120+'\n')
# Out:
# columns: appetite
# Counter({'good': 318, 'poor': 82})
# ************************************************************************************************************************
#
# columns: diabetesmellitus
# Counter({'no': 260, 'yes': 134, '\tno': 3, '\tyes': 2, ' yes': 1})
# ************************************************************************************************************************
#
# columns: class
# Counter({'ckd': 248, 'notckd': 150, 'ckd\t': 2})
# ************************************************************************************************************************
#
# columns: pus_cell_clumps
# Counter({'notpresent': 358, 'present': 42})
# ************************************************************************************************************************
#
# columns: anemia
# Counter({'no': 340, 'yes': 60})
# ************************************************************************************************************************
#
# columns: coronary_artery_disease
# Counter({'no': 364, 'yes': 34, '\tno': 2})
# ************************************************************************************************************************
#
# columns: pus_cell
# Counter({'normal': 324, 'abnormal': 76})
# ************************************************************************************************************************
#
# columns: pedal_edema
# Counter({'no': 324, 'yes': 76})
# ************************************************************************************************************************
#
# columns: hypertension
# Counter({'no': 253, 'yes': 147})
# ************************************************************************************************************************
#
# columns: bacteria
# Counter({'notpresent': 378, 'present': 22})
# ************************************************************************************************************************
#
# columns: red_blood_cells
# Counter({'normal': 353, 'abnormal': 47})
# ************************************************************************************************************************

# %%
catcols = ['anemia',
 'appetite',
 'bacteria',
 'class',
 'coronary_artery_disease',
 'diabetesmellitus',
 'hypertension',
 'pedal_edema',
 'pus_cell',
 'pus_cell_clumps',
 'red_blood_cells']

# %%
data.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood gulcose random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# hemoglobin                 float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetesmellitus            object
# coronary_artery_disease     object
# appetite                    object
# pedal_edema                 object
# anemia                      object
# class                       object
# dtype: object

# %%
from prompt_toolkit.shortcuts.progress_bar.formatters import Label
from sklearn.preprocessing import LabelEncoder
for i in catcols:
  print("Label Encodings of :",i)
  LEi = LabelEncoder()
  print(c(data[i]))
  data[i] = LEi.fit_transform(data[i])
  print(c(data[i]))
  print("*"*100)
# Out:
# Label Encodings of : anemia
# Counter({'no': 340, 'yes': 60})
# Counter({0: 340, 1: 60})
# ****************************************************************************************************
# Label Encodings of : appetite
# Counter({'good': 318, 'poor': 82})
# Counter({0: 318, 1: 82})
# ****************************************************************************************************
# Label Encodings of : bacteria
# Counter({'notpresent': 378, 'present': 22})
# Counter({0: 378, 1: 22})
# ****************************************************************************************************
# Label Encodings of : class
# Counter({'ckd': 248, 'notckd': 150, 'ckd\t': 2})
# Counter({0: 248, 2: 150, 1: 2})
# ****************************************************************************************************
# Label Encodings of : coronary_artery_disease
# Counter({'no': 364, 'yes': 34, '\tno': 2})
# Counter({1: 364, 2: 34, 0: 2})
# ****************************************************************************************************
# Label Encodings of : diabetesmellitus
# Counter({'no': 260, 'yes': 134, '\tno': 3, '\tyes': 2, ' yes': 1})
# Counter({3: 260, 4: 134, 0: 3, 1: 2, 2: 1})
# ****************************************************************************************************
# Label Encodings of : hypertension
# Counter({'no': 253, 'yes': 147})
# Counter({0: 253, 1: 147})
# ****************************************************************************************************
# Label Encodings of : pedal_edema
# Counter({'no': 324, 'yes': 76})
# Counter({0: 324, 1: 76})
# ****************************************************************************************************
# Label Encodings of : pus_cell
# Counter({'normal': 324, 'abnormal': 76})
# Counter({1: 324, 0: 76})
# ****************************************************************************************************
# Label Encodings of : pus_cell_clumps
# Counter({'notpresent': 358, 'present': 42})
# Counter({0: 358, 1: 42})
# ****************************************************************************************************
# Label Encodings of : red_blood_cells
# Counter({'normal': 353, 'abnormal': 47})
# Counter({1: 353, 0: 47})
# ****************************************************************************************************

# %%
data.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells              int64
# pus_cell                     int64
# pus_cell_clumps              int64
# bacteria                     int64
# blood gulcose random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# hemoglobin                 float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                 int64
# diabetesmellitus             int64
# coronary_artery_disease      int64
# appetite                     int64
# pedal_edema                  int64
# anemia                       int64
# class                        int64
# dtype: object

# %%
contcols = set(data.dtypes[data.dtypes !='O'].index.values)
print(contcols)
# Out:
# {'pedal_edema', 'red_blood_cell_count', 'albumin', 'packed_cell_volume', 'blood_pressure', 'specific_gravity', 'potassium', 'diabetesmellitus', 'class', 'blood_urea', 'pus_cell', 'hemoglobin', 'anemia', 'appetite', 'blood gulcose random', 'white_blood_cell_count', 'bacteria', 'serum_creatinine', 'hypertension', 'pus_cell_clumps', 'coronary_artery_disease', 'sodium', 'red_blood_cells', 'age', 'sugar'}

# %%
for i in contcols:
  print("continous Columns:", i)
  print(c(data[i]))
  print('*'*120+'\n')
# Out:
# continous Columns: pedal_edema
# Counter({0: 324, 1: 76})
# ************************************************************************************************************************
#
# continous Columns: red_blood_cell_count
# Counter({4.707434944237917: 131, 5.2: 18, 4.5: 16, 4.9: 14, 4.7: 11, 3.9: 10, 5.0: 10, 4.8: 10, 4.6: 9, 3.4: 9, 3.7: 8, 6.1: 8, 5.5: 8, 5.9: 8, 3.8: 7, 5.4: 7, 5.8: 7, 5.3: 7, 4.0: 6, 4.3: 6, 4.2: 6, 5.6: 6, 4.4: 5, 3.2: 5, 4.1: 5, 6.2: 5, 5.1: 5, 6.4: 5, 5.7: 5, 6.5: 5, 3.6: 4, 6.0: 4, 6.3: 4, 3.5: 3, 3.3: 3, 3.0: 3, 2.6: 2, 2.8: 2, 2.5: 2, 3.1: 2, 2.1: 2, 2.9: 2, 2.7: 2, 2.3: 1, 8.0: 1, 2.4: 1})
# ************************************************************************************************************************
#
# continous Columns: albumin
# Counter({0.0: 245, 1.0: 44, 2.0: 43, 3.0: 43, 4.0: 24, 5.0: 1})
# ************************************************************************************************************************
#
# continous Columns: packed_cell_volume
# Counter({38.88449848024316: 71, 52.0: 21, 41.0: 21, 44.0: 19, 48.0: 19, 40.0: 16, 43.0: 15, 45.0: 13, 42.0: 13, 32.0: 12, 36.0: 12, 33.0: 12, 28.0: 12, 50.0: 12, 37.0: 11, 34.0: 11, 35.0: 9, 29.0: 9, 30.0: 9, 46.0: 9, 31.0: 8, 39.0: 7, 24.0: 7, 26.0: 6, 38.0: 5, 47.0: 4, 49.0: 4, 53.0: 4, 51.0: 4, 54.0: 4, 27.0: 3, 22.0: 3, 25.0: 3, 23.0: 2, 19.0: 2, 16.0: 1, 14.0: 1, 18.0: 1, 17.0: 1, 15.0: 1, 21.0: 1, 20.0: 1, 9.0: 1})
# ************************************************************************************************************************
#
# continous Columns: blood_pressure
# Counter({80.0: 116, 70.0: 112, 60.0: 71, 90.0: 53, 100.0: 25, 76.46907216494846: 12, 50.0: 5, 110.0: 3, 140.0: 1, 180.0: 1, 120.0: 1})
# ************************************************************************************************************************
#
# continous Columns: specific_gravity
# Counter({1.02: 153, 1.01: 84, 1.025: 81, 1.015: 75, 1.005: 7})
# ************************************************************************************************************************
#
# continous Columns: potassium
# Counter({4.62724358974359: 88, 5.0: 30, 3.5: 30, 4.9: 27, 4.7: 17, 4.8: 16, 4.0: 14, 4.2: 14, 4.1: 14, 3.8: 14, 3.9: 14, 4.4: 14, 4.5: 13, 3.7: 12, 4.3: 12, 3.6: 8, 4.6: 7, 3.4: 5, 5.2: 5, 5.7: 4, 5.3: 4, 3.2: 3, 5.5: 3, 2.9: 3, 5.4: 3, 6.3: 3, 3.3: 3, 2.5: 2, 5.8: 2, 5.9: 2, 5.6: 2, 3.0: 2, 6.5: 2, 6.4: 1, 6.6: 1, 39.0: 1, 7.6: 1, 47.0: 1, 5.1: 1, 2.8: 1, 2.7: 1})
# ************************************************************************************************************************
#
# continous Columns: diabetesmellitus
# Counter({3: 260, 4: 134, 0: 3, 1: 2, 2: 1})
# ************************************************************************************************************************
#
# continous Columns: class
# Counter({0: 248, 2: 150, 1: 2})
# ************************************************************************************************************************
#
# continous Columns: blood_urea
# Counter({57.425721784776904: 19, 46.0: 15, 25.0: 13, 19.0: 11, 40.0: 10, 18.0: 9, 50.0: 9, 15.0: 9, 48.0: 9, 26.0: 8, 27.0: 8, 32.0: 8, 49.0: 8, 36.0: 7, 28.0: 7, 20.0: 7, 17.0: 7, 38.0: 7, 16.0: 7, 30.0: 7, 44.0: 7, 31.0: 6, 45.0: 6, 39.0: 6, 29.0: 6, 24.0: 6, 37.0: 6, 22.0: 6, 23.0: 6, 53.0: 5, 55.0: 5, 33.0: 5, 66.0: 5, 35.0: 5, 42.0: 5, 47.0: 4, 51.0: 4, 34.0: 4, 68.0: 4, 41.0: 4, 60.0: 3, 107.0: 3, 80.0: 3, 96.0: 3, 52.0: 3, 106.0: 3, 125.0: 3, 56.0: 2, 54.0: 2, 72.0: 2, 86.0: 2, 90.0: 2, 87.0: 2, 155.0: 2, 153.0: 2, 77.0: 2, 89.0: 2, 111.0: 2, 73.0: 2, 98.0: 2, 82.0: 2, 132.0: 2, 58.0: 2, 10.0: 2, 162.0: 1, 148.0: 1, 180.0: 1, 163.0: 1, 75.0: 1, 65.0: 1, 103.0: 1, 70.0: 1, 202.0: 1, 114.0: 1, 164.0: 1, 142.0: 1, 391.0: 1, 92.0: 1, 139.0: 1, 85.0: 1, 186.0: 1, 217.0: 1, 88.0: 1, 118.0: 1, 50.1: 1, 71.0: 1, 21.0: 1, 219.0: 1, 166.0: 1, 208.0: 1, 176.0: 1, 145.0: 1, 165.0: 1, 322.0: 1, 235.0: 1, 76.0: 1, 113.0: 1, 1.5: 1, 146.0: 1, 133.0: 1, 137.0: 1, 67.0: 1, 115.0: 1, 223.0: 1, 98.6: 1, 158.0: 1, 94.0: 1, 74.0: 1, 150.0: 1, 61.0: 1, 57.0: 1, 95.0: 1, 191.0: 1, 93.0: 1, 241.0: 1, 64.0: 1, 79.0: 1, 215.0: 1, 309.0: 1})
# ************************************************************************************************************************
#
# continous Columns: pus_cell
# Counter({1: 324, 0: 76})
# ************************************************************************************************************************
#
# continous Columns: hemoglobin
# Counter({12.526436781609195: 52, 15.0: 16, 10.9: 8, 9.8: 7, 11.1: 7, 13.0: 7, 13.6: 7, 11.3: 6, 10.3: 6, 12.0: 6, 13.9: 6, 15.4: 5, 11.2: 5, 10.8: 5, 9.7: 5, 12.6: 5, 7.9: 5, 10.0: 5, 14.0: 5, 14.3: 5, 14.8: 5, 12.2: 4, 12.4: 4, 12.5: 4, 15.2: 4, 9.1: 4, 11.9: 4, 13.5: 4, 16.1: 4, 14.1: 4, 13.2: 4, 13.8: 4, 13.7: 4, 13.4: 4, 17.0: 4, 15.5: 4, 15.8: 4, 9.6: 3, 11.6: 3, 9.5: 3, 9.4: 3, 12.7: 3, 9.9: 3, 10.1: 3, 8.6: 3, 11.0: 3, 15.6: 3, 8.1: 3, 8.3: 3, 10.4: 3, 11.8: 3, 11.4: 3, 11.5: 3, 15.9: 3, 14.5: 3, 16.2: 3, 14.4: 3, 14.2: 3, 16.3: 3, 16.5: 3, 15.7: 3, 16.4: 3, 14.9: 3, 15.3: 3, 17.8: 3, 12.1: 2, 9.3: 2, 10.2: 2, 10.5: 2, 6.0: 2, 11.7: 2, 8.0: 2, 12.3: 2, 8.7: 2, 13.1: 2, 8.8: 2, 13.3: 2, 14.6: 2, 16.9: 2, 16.0: 2, 14.7: 2, 16.6: 2, 16.7: 2, 16.8: 2, 15.1: 2, 17.1: 2, 17.2: 2, 17.4: 2, 5.6: 1, 7.6: 1, 7.7: 1, 12.9: 1, 6.6: 1, 7.5: 1, 4.8: 1, 7.1: 1, 9.2: 1, 6.2: 1, 8.2: 1, 6.1: 1, 8.4: 1, 9.0: 1, 10.6: 1, 10.7: 1, 5.5: 1, 5.8: 1, 6.8: 1, 8.5: 1, 7.3: 1, 12.8: 1, 6.3: 1, 3.1: 1, 17.3: 1, 17.7: 1, 17.5: 1, 17.6: 1})
# ************************************************************************************************************************
#
# continous Columns: anemia
# Counter({0: 340, 1: 60})
# ************************************************************************************************************************
#
# continous Columns: appetite
# Counter({0: 318, 1: 82})
# ************************************************************************************************************************
#
# continous Columns: blood gulcose random
# Counter({148.0365168539326: 44, 99.0: 10, 100.0: 9, 93.0: 9, 107.0: 8, 117.0: 6, 140.0: 6, 92.0: 6, 109.0: 6, 131.0: 6, 130.0: 6, 70.0: 5, 114.0: 5, 95.0: 5, 123.0: 5, 124.0: 5, 102.0: 5, 132.0: 5, 104.0: 5, 125.0: 5, 122.0: 5, 121.0: 4, 106.0: 4, 76.0: 4, 91.0: 4, 129.0: 4, 133.0: 4, 94.0: 4, 88.0: 4, 118.0: 4, 139.0: 4, 111.0: 4, 113.0: 4, 120.0: 4, 119.0: 4, 74.0: 3, 108.0: 3, 171.0: 3, 137.0: 3, 79.0: 3, 150.0: 3, 112.0: 3, 127.0: 3, 219.0: 3, 172.0: 3, 89.0: 3, 128.0: 3, 214.0: 3, 105.0: 3, 78.0: 3, 103.0: 3, 82.0: 3, 97.0: 3, 81.0: 3, 138.0: 2, 490.0: 2, 208.0: 2, 98.0: 2, 204.0: 2, 207.0: 2, 144.0: 2, 253.0: 2, 141.0: 2, 86.0: 2, 360.0: 2, 163.0: 2, 158.0: 2, 165.0: 2, 169.0: 2, 210.0: 2, 101.0: 2, 153.0: 2, 213.0: 2, 424.0: 2, 303.0: 2, 192.0: 2, 80.0: 2, 110.0: 2, 96.0: 2, 85.0: 2, 83.0: 2, 75.0: 2, 423.0: 1, 410.0: 1, 380.0: 1, 157.0: 1, 263.0: 1, 173.0: 1, 156.0: 1, 264.0: 1, 159.0: 1, 270.0: 1, 162.0: 1, 246.0: 1, 182.0: 1, 146.0: 1, 425.0: 1, 250.0: 1, 415.0: 1, 251.0: 1, 280.0: 1, 295.0: 1, 298.0: 1, 226.0: 1, 143.0: 1, 115.0: 1, 297.0: 1, 233.0: 1, 294.0: 1, 323.0: 1, 90.0: 1, 308.0: 1, 224.0: 1, 268.0: 1, 256.0: 1, 84.0: 1, 288.0: 1, 273.0: 1, 242.0: 1, 148.0: 1, 160.0: 1, 307.0: 1, 220.0: 1, 447.0: 1, 309.0: 1, 22.0: 1, 261.0: 1, 215.0: 1, 234.0: 1, 352.0: 1, 239.0: 1, 184.0: 1, 252.0: 1, 230.0: 1, 341.0: 1, 255.0: 1, 238.0: 1, 248.0: 1, 241.0: 1, 269.0: 1, 201.0: 1, 203.0: 1, 463.0: 1, 176.0: 1, 116.0: 1, 134.0: 1, 87.0: 1})
# ************************************************************************************************************************
#
# continous Columns: white_blood_cell_count
# Counter({8406.122448979591: 106, 9800.0: 11, 6700.0: 10, 9600.0: 9, 9200.0: 9, 7200.0: 9, 6900.0: 8, 11000.0: 8, 5800.0: 8, 7800.0: 7, 9100.0: 7, 9400.0: 7, 7000.0: 7, 4300.0: 6, 6300.0: 6, 10700.0: 6, 10500.0: 6, 7500.0: 5, 6200.0: 5, 8300.0: 5, 7900.0: 5, 8600.0: 5, 5600.0: 5, 10200.0: 5, 5000.0: 5, 8100.0: 5, 9500.0: 5, 6000.0: 4, 8400.0: 4, 10300.0: 4, 7700.0: 4, 5500.0: 4, 10400.0: 4, 6800.0: 4, 6500.0: 4, 4700.0: 4, 7300.0: 3, 4500.0: 3, 6400.0: 3, 4200.0: 3, 7400.0: 3, 8000.0: 3, 5400.0: 3, 3800.0: 2, 11400.0: 2, 5300.0: 2, 8500.0: 2, 14600.0: 2, 7100.0: 2, 13200.0: 2, 9000.0: 2, 8200.0: 2, 15200.0: 2, 12400.0: 2, 12800.0: 2, 8800.0: 2, 5700.0: 2, 9300.0: 2, 6600.0: 2, 12100.0: 1, 12200.0: 1, 18900.0: 1, 21600.0: 1, 11300.0: 1, 11800.0: 1, 12500.0: 1, 11900.0: 1, 12700.0: 1, 13600.0: 1, 14900.0: 1, 16300.0: 1, 10900.0: 1, 2200.0: 1, 11200.0: 1, 19100.0: 1, 12300.0: 1, 16700.0: 1, 2600.0: 1, 26400.0: 1, 4900.0: 1, 12000.0: 1, 15700.0: 1, 4100.0: 1, 11500.0: 1, 10800.0: 1, 9900.0: 1, 5200.0: 1, 5900.0: 1, 9700.0: 1, 5100.0: 1})
# ************************************************************************************************************************
#
# continous Columns: bacteria
# Counter({0: 378, 1: 22})
# ************************************************************************************************************************
#
# continous Columns: serum_creatinine
# Counter({1.2: 40, 1.1: 24, 1.0: 23, 0.5: 23, 0.7: 22, 0.9: 22, 0.6: 18, 0.8: 17, 3.072454308093995: 17, 2.2: 10, 1.5: 9, 1.7: 9, 1.3: 8, 1.6: 8, 1.8: 7, 1.4: 7, 2.5: 7, 2.8: 7, 1.9: 6, 2.7: 5, 2.1: 5, 2.0: 5, 3.2: 5, 3.3: 5, 3.9: 4, 7.3: 4, 4.0: 3, 2.4: 3, 3.4: 3, 2.9: 3, 5.3: 3, 2.3: 3, 7.2: 2, 4.6: 2, 4.1: 2, 5.2: 2, 6.3: 2, 3.0: 2, 6.1: 2, 6.7: 2, 5.6: 2, 6.5: 2, 4.4: 2, 6.0: 2, 3.8: 1, 24.0: 1, 9.6: 1, 76.0: 1, 7.7: 1, 10.8: 1, 5.9: 1, 3.25: 1, 9.7: 1, 6.4: 1, 32.0: 1, 8.5: 1, 15.0: 1, 3.6: 1, 10.2: 1, 11.5: 1, 12.2: 1, 9.2: 1, 13.8: 1, 16.9: 1, 7.1: 1, 18.0: 1, 13.0: 1, 48.1: 1, 14.2: 1, 16.4: 1, 2.6: 1, 7.5: 1, 4.3: 1, 18.1: 1, 11.8: 1, 9.3: 1, 6.8: 1, 13.5: 1, 12.8: 1, 11.9: 1, 12.0: 1, 13.4: 1, 15.2: 1, 13.3: 1, 0.4: 1})
# ************************************************************************************************************************
#
# continous Columns: hypertension
# Counter({0: 253, 1: 147})
# ************************************************************************************************************************
#
# continous Columns: pus_cell_clumps
# Counter({0: 358, 1: 42})
# ************************************************************************************************************************
#
# continous Columns: coronary_artery_disease
# Counter({1: 364, 2: 34, 0: 2})
# ************************************************************************************************************************
#
# continous Columns: sodium
# Counter({137.52875399361022: 87, 135.0: 40, 140.0: 25, 141.0: 22, 139.0: 21, 142.0: 20, 138.0: 20, 137.0: 19, 136.0: 17, 150.0: 17, 147.0: 13, 145.0: 11, 132.0: 10, 146.0: 10, 131.0: 9, 144.0: 9, 133.0: 8, 130.0: 7, 134.0: 6, 143.0: 4, 127.0: 3, 124.0: 3, 114.0: 2, 125.0: 2, 128.0: 2, 122.0: 2, 113.0: 2, 120.0: 2, 111.0: 1, 104.0: 1, 4.5: 1, 129.0: 1, 163.0: 1, 126.0: 1, 115.0: 1})
# ************************************************************************************************************************
#
# continous Columns: red_blood_cells
# Counter({1: 353, 0: 47})
# ************************************************************************************************************************
#
# continous Columns: age
# Counter({60.0: 28, 65.0: 17, 48.0: 12, 50.0: 12, 55.0: 12, 47.0: 11, 62.0: 10, 45.0: 10, 54.0: 10, 59.0: 10, 56.0: 10, 61.0: 9, 70.0: 9, 46.0: 9, 34.0: 9, 68.0: 8, 73.0: 8, 64.0: 8, 71.0: 8, 57.0: 8, 63.0: 7, 72.0: 7, 67.0: 7, 30.0: 7, 42.0: 6, 69.0: 6, 35.0: 6, 44.0: 6, 43.0: 6, 33.0: 6, 51.0: 5, 52.0: 5, 53.0: 5, 75.0: 5, 76.0: 5, 58.0: 5, 41.0: 5, 66.0: 5, 24.0: 4, 40.0: 4, 39.0: 4, 80.0: 4, 23.0: 4, 74.0: 3, 38.0: 3, 17.0: 3, 8.0: 3, 32.0: 3, 37.0: 3, 25.0: 3, 29.0: 3, 21.0: 2, 15.0: 2, 5.0: 2, 12.0: 2, 49.0: 2, 19.0: 2, 36.0: 2, 20.0: 2, 28.0: 2, 7.0: 1, 82.0: 1, 11.0: 1, 26.0: 1, 81.0: 1, 14.0: 1, 27.0: 1, 83.0: 1, 4.0: 1, 3.0: 1, 6.0: 1, 90.0: 1, 78.0: 1, 2.0: 1, 22.0: 1, 79.0: 1})
# ************************************************************************************************************************
#
# continous Columns: sugar
# Counter({0.0: 339, 2.0: 18, 3.0: 14, 4.0: 13, 1.0: 13, 5.0: 3})
# ************************************************************************************************************************

# %%
contcols.remove('albumin')
contcols.remove('sugar')
contcols.remove('specific_gravity')
contcols
# Out:
# {'age',
#  'anemia',
#  'appetite',
#  'bacteria',
#  'blood gulcose random',
#  'blood_pressure',
#  'blood_urea',
#  'class',
#  'coronary_artery_disease',
#  'diabetesmellitus',
#  'hemoglobin',
#  'hypertension',
#  'packed_cell_volume',
#  'pedal_edema',
#  'potassium',
#  'pus_cell',
#  'pus_cell_clumps',
#  'red_blood_cell_count',
#  'red_blood_cells',
#  'serum_creatinine',
#  'sodium',
#  'white_blood_cell_count'}

# %%
catcols.append('specific_gravity')
catcols.append('sugar')
catcols.append('albumin')
catcols
# Out:
# ['anemia',
#  'appetite',
#  'bacteria',
#  'class',
#  'coronary_artery_disease',
#  'diabetesmellitus',
#  'hypertension',
#  'pedal_edema',
#  'pus_cell',
#  'pus_cell_clumps',
#  'red_blood_cells',
#  'specific_gravity',
#  'sugar',
#  'albumin']

# %%
contcols.add('red_blood_cell_count')
contcols.add('packed_cell_volume')
contcols.add('white_blood_cell_count')
print(contcols)
# Out:
# {'pedal_edema', 'red_blood_cell_count', 'packed_cell_volume', 'blood_pressure', 'potassium', 'diabetesmellitus', 'class', 'blood_urea', 'pus_cell', 'hemoglobin', 'anemia', 'appetite', 'blood gulcose random', 'white_blood_cell_count', 'bacteria', 'serum_creatinine', 'hypertension', 'pus_cell_clumps', 'coronary_artery_disease', 'sodium', 'red_blood_cells', 'age'}

# %%
data['coronary_artery_disease'] = data.coronary_artery_disease.replace('tno','no')

# %%
c(data['coronary_artery_disease'])
# Out:
# Counter({1: 364, 2: 34, 0: 2})

# %%
data['diabetesmellitus'] = data.diabetesmellitus.replace('\tno','no')
data['diabetesmellitus'] = data.diabetesmellitus.replace('\tyes','yes')

# %%
c(data['diabetesmellitus'])
# Out:
# Counter({4: 134, 3: 260, 2: 1, 0: 3, 1: 2})

# %% [markdown]
# Describe() to find mean,mode,etc.

# %%
data.describe()
# Out:
#               age  blood_pressure  specific_gravity    albumin       sugar  \
# count  400.000000      400.000000        400.000000  400.00000  400.000000
# mean    51.675000       76.469072          1.017712    0.90000    0.395000
# std     17.022008       13.476298          0.005434    1.31313    1.040038
# min      2.000000       50.000000          1.005000    0.00000    0.000000
# 25%     42.000000       70.000000          1.015000    0.00000    0.000000
# 50%     55.000000       78.234536          1.020000    0.00000    0.000000
# 75%     64.000000       80.000000          1.020000    2.00000    0.000000
# max     90.000000      180.000000          1.025000    5.00000    5.000000
#
#        red_blood_cells    pus_cell  pus_cell_clumps    bacteria  \
# count       400.000000  400.000000       400.000000  400.000000
# mean          0.882500    0.810000         0.105000    0.055000
# std           0.322418    0.392792         0.306937    0.228266
# min           0.000000    0.000000         0.000000    0.000000
# 25%           1.000000    1.000000         0.000000    0.000000
# 50%           1.000000    1.000000         0.000000    0.000000
# 75%           1.000000    1.000000         0.000000    0.000000
# max           1.000000    1.000000         1.000000    1.000000
#
#        blood gulcose random  ...  packed_cell_volume  white_blood_cell_count  \
# count            400.000000  ...          400.000000              400.000000
# mean             148.036517  ...           38.884498             8406.122449
# std               74.782634  ...            8.151081             2523.219976
# min               22.000000  ...            9.000000             2200.000000
# 25%              101.000000  ...           34.000000             6975.000000
# 50%              126.000000  ...           38.884498             8406.122449
# 75%              150.000000  ...           44.000000             9400.000000
# max              490.000000  ...           54.000000            26400.000000
#
#        red_blood_cell_count  hypertension  diabetesmellitus  \
# count            400.000000    400.000000        400.000000
# mean               4.707435      0.367500          3.300000
# std                0.840314      0.482728          0.579517
# min                2.100000      0.000000          0.000000
# 25%                4.500000      0.000000          3.000000
# 50%                4.707435      0.000000          3.000000
# 75%                5.100000      1.000000          4.000000
# max                8.000000      1.000000          4.000000
#
#        coronary_artery_disease    appetite  pedal_edema      anemia  \
# count               400.000000  400.000000   400.000000  400.000000
# mean                  1.080000    0.205000     0.190000    0.150000
# std                   0.289499    0.404207     0.392792    0.357519
# min                   0.000000    0.000000     0.000000    0.000000
# 25%                   1.000000    0.000000     0.000000    0.000000
# 50%                   1.000000    0.000000     0.000000    0.000000
# 75%                   1.000000    0.000000     0.000000    0.000000
# max                   2.000000    1.000000     1.000000    1.000000
#
#             class
# count  400.000000
# mean     0.755000
# std      0.968152
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      2.000000
# max      2.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# Univariate Analysis

# %%
sns.distplot(data.age)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# Bivariate Analysis

# %%
fig=plt.figure(figsize =(12,6))
plt.scatter(data['age'],data['blood_pressure'],color='blue')
plt.xlabel('Age')
plt.ylabel('Blood pressure')
plt.title("age vs Blood_pressure")
# Out:
# Text(0.5, 1.0, 'age vs Blood_pressure')

# %% [markdown]
# Multivariate Analysis

# %%
plt.figure(figsize=(20,15),facecolor='white')
plotnumber = 1

for column in contcols:
  if plotnumber<=11:
    ax = plt.subplot(3,4,plotnumber)
    plt.scatter(data['age'],data[column])
    plt.xlabel(column,fontsize=20)
    plt.ylabel('age',fontsize=20)
  plotnumber+=1
plt.show()

# %%
f,ax =plt.subplots(figsize=(18,10))
sns.heatmap(data.corr(),annot = True,fmt = ".2f",ax=ax,linewidths=0.5,linecolor="orange")
plt.xticks(rotation = 90)
plt.yticks(rotation = 45)
plt.show()

# %%
sns.countplot(data['class'])
# Out:
# <Axes: ylabel='count'>

# %%
selcols = ['red_blood_cells','pus_cell','blood gulcose random','blood_urea','pedal_edema','anemia','diabetesmellitus','coronary_artery_disease']
x= pd.DataFrame(data,columns=selcols)
y=pd.DataFrame(data,columns=['class'])
print(x.shape)
print(y.shape)
# Out:
# (400, 8)
# (400, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_bal=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
classification = Sequential()
classification.add(Dense(30,activation='relu'))
classification.add(Dense(128,activation='relu'))
classification.add(Dense(64,activation='relu'))
classification.add(Dense(32,activation='relu'))
classification.add(Dense(1,activation='sigmoid'))

# %%
classification.compile(optimizer='adam',loss = 'binary_crossentropy',metrics=['accuracy'])

# %%
classification.fit(x_train,y_train,batch_size = 10,validation_split=0.2,epochs=100)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 2s 12ms/step - loss: 1.2826 - accuracy: 0.2734 - val_loss: 1.8151 - val_accuracy: 0.1250
# Epoch 2/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6185 - accuracy: 0.2344 - val_loss: 0.3552 - val_accuracy: 0.2812
# Epoch 3/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.4586 - accuracy: 0.2461 - val_loss: 0.3598 - val_accuracy: 0.4375
# Epoch 4/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3617 - accuracy: 0.2773 - val_loss: 0.6001 - val_accuracy: 0.2344
# Epoch 5/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3652 - accuracy: 0.2500 - val_loss: 1.2136 - val_accuracy: 0.6562
# Epoch 6/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.3438 - val_loss: 0.5784 - val_accuracy: 0.1562
# Epoch 7/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7650 - accuracy: 0.2188 - val_loss: 0.2907 - val_accuracy: 0.2969
# Epoch 8/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3046 - accuracy: 0.2969 - val_loss: 0.4792 - val_accuracy: 0.1875
# Epoch 9/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0607 - accuracy: 0.2617 - val_loss: 0.4511 - val_accuracy: 0.5156
# Epoch 10/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3849 - accuracy: 0.3086 - val_loss: 0.4309 - val_accuracy: 0.2500
# Epoch 11/100
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1093 - accuracy: 0.2695 - val_loss: 0.0138 - val_accuracy: 0.3438
# Epoch 12/100
# 26/26 [==============================] - 0s 4ms/step - loss: -0.0541 - accuracy: 0.2812 - val_loss: 0.8720 - val_accuracy: 0.1875
# Epoch 13/100
# 26/26 [==============================] - 0s 3ms/step - loss: -0.0397 - accuracy: 0.2852 - val_loss: -0.0310 - val_accuracy: 0.2812
# Epoch 14/100
# 26/26 [==============================] - 0s 4ms/step - loss: -0.2775 - accuracy: 0.2891 - val_loss: 0.1130 - val_accuracy: 0.2344
# Epoch 15/100
# 26/26 [==============================] - 0s 4ms/step - loss: -0.5524 - accuracy: 0.2852 - val_loss: -0.2720 - val_accuracy: 0.3750
# Epoch 16/100
# 26/26 [==============================] - 0s 4ms/step - loss: -0.5974 - accuracy: 0.2891 - val_loss: -0.1772 - val_accuracy: 0.2969
# Epoch 17/100
# 26/26 [==============================] - 0s 3ms/step - loss: -0.4642 - accuracy: 0.3320 - val_loss: 0.9004 - val_accuracy: 0.2031
# Epoch 18/100
# 26/26 [==============================] - 0s 4ms/step - loss: -0.8018 - accuracy: 0.2773 - val_loss: -0.4005 - val_accuracy: 0.2656
# Epoch 19/100
# 26/26 [==============================] - 0s 4ms/step - loss: -0.8240 - accuracy: 0.3203 - val_loss: 0.5071 - val_accuracy: 0.1875
# Epoch 20/100
# 26/26 [==============================] - 0s 4ms/step - loss: -1.1082 - accuracy: 0.2930 - val_loss: -0.4218 - val_accuracy: 0.5000
# Epoch 21/100
# 26/26 [==============================] - 0s 4ms/step - loss: -2.3218 - accuracy: 0.3125 - val_loss: -0.4984 - val_accuracy: 0.2812
# Epoch 22/100
# 26/26 [==============================] - 0s 4ms/step - loss: -2.6151 - accuracy: 0.2969 - val_loss: -1.8058 - val_accuracy: 0.3125
# Epoch 23/100
# 26/26 [==============================] - 0s 5ms/step - loss: -4.2498 - accuracy: 0.3242 - val_loss: -2.1393 - val_accuracy: 0.3281
# Epoch 24/100
# 26/26 [==============================] - 0s 4ms/step - loss: -4.7697 - accuracy: 0.3086 - val_loss: -3.8375 - val_accuracy: 0.3125
# Epoch 25/100
# 26/26 [==============================] - 0s 3ms/step - loss: -9.7140 - accuracy: 0.3438 - val_loss: -1.1490 - val_accuracy: 0.2344
# Epoch 26/100
# 26/26 [==============================] - 0s 4ms/step - loss: -12.4509 - accuracy: 0.2969 - val_loss: -2.5885 - val_accuracy: 0.4844
# Epoch 27/100
# 26/26 [==============================] - 0s 4ms/step - loss: -10.6734 - accuracy: 0.3047 - val_loss: -5.2416 - val_accuracy: 0.5469
# Epoch 28/100
# 26/26 [==============================] - 0s 4ms/step - loss: -14.9048 - accuracy: 0.3281 - val_loss: -15.2363 - val_accuracy: 0.3125
# Epoch 29/100
# 26/26 [==============================] - 0s 4ms/step - loss: -35.0132 - accuracy: 0.3320 - val_loss: -22.7428 - val_accuracy: 0.4219
# Epoch 30/100
# 26/26 [==============================] - 0s 4ms/step - loss: -57.6002 - accuracy: 0.3320 - val_loss: 7.5698 - val_accuracy: 0.2188
# Epoch 31/100
# 26/26 [==============================] - 0s 4ms/step - loss: -48.5622 - accuracy: 0.3086 - val_loss: -52.4731 - val_accuracy: 0.4844
# Epoch 32/100
# 26/26 [==============================] - 0s 4ms/step - loss: -102.0272 - accuracy: 0.3203 - val_loss: -77.7910 - val_accuracy: 0.3281
# Epoch 33/100
# 26/26 [==============================] - 0s 4ms/step - loss: -198.8353 - accuracy: 0.3203 - val_loss: -109.2118 - val_accuracy: 0.3281
# Epoch 34/100
# 26/26 [==============================] - 0s 4ms/step - loss: -271.1904 - accuracy: 0.3125 - val_loss: 114.7685 - val_accuracy: 0.1875
# Epoch 35/100
# 26/26 [==============================] - 0s 3ms/step - loss: -349.0862 - accuracy: 0.3164 - val_loss: -258.6128 - val_accuracy: 0.4375
# Epoch 36/100
# 26/26 [==============================] - 0s 3ms/step - loss: -567.4803 - accuracy: 0.3438 - val_loss: -503.0343 - val_accuracy: 0.3906
# Epoch 37/100
# 26/26 [==============================] - 0s 4ms/step - loss: -813.6096 - accuracy: 0.3281 - val_loss: -205.9444 - val_accuracy: 0.2656
# Epoch 38/100
# 26/26 [==============================] - 0s 3ms/step - loss: -1097.8533 - accuracy: 0.3125 - val_loss: -593.5720 - val_accuracy: 0.2500
# Epoch 39/100
# 26/26 [==============================] - 0s 4ms/step - loss: -1797.2051 - accuracy: 0.3203 - val_loss: -1220.9550 - val_accuracy: 0.3906
# Epoch 40/100
# 26/26 [==============================] - 0s 3ms/step - loss: -2454.2236 - accuracy: 0.3281 - val_loss: -1101.5807 - val_accuracy: 0.3438
# Epoch 41/100
# 26/26 [==============================] - 0s 4ms/step - loss: -3316.2781 - accuracy: 0.3359 - val_loss: -2064.7878 - val_accuracy: 0.3438
# Epoch 42/100
# 26/26 [==============================] - 0s 4ms/step - loss: -4412.7812 - accuracy: 0.3320 - val_loss: -2259.5059 - val_accuracy: 0.2969
# Epoch 43/100
# 26/26 [==============================] - 0s 4ms/step - loss: -5041.3125 - accuracy: 0.3047 - val_loss: -2622.8042 - val_accuracy: 0.2188
# Epoch 44/100
# 26/26 [==============================] - 0s 4ms/step - loss: -7549.0571 - accuracy: 0.3164 - val_loss: -4195.1597 - val_accuracy: 0.2969
# Epoch 45/100
# 26/26 [==============================] - 0s 3ms/step - loss: -8535.4590 - accuracy: 0.3242 - val_loss: -5257.3242 - val_accuracy: 0.3750
# Epoch 46/100
# 26/26 [==============================] - 0s 4ms/step - loss: -11622.4072 - accuracy: 0.3398 - val_loss: -6114.5146 - val_accuracy: 0.3281
# Epoch 47/100
# 26/26 [==============================] - 0s 4ms/step - loss: -13748.4668 - accuracy: 0.3281 - val_loss: -3207.5920 - val_accuracy: 0.2344
# Epoch 48/100
# 26/26 [==============================] - 0s 4ms/step - loss: -16005.4072 - accuracy: 0.3125 - val_loss: -9400.2031 - val_accuracy: 0.3281
# Epoch 49/100
# 26/26 [==============================] - 0s 4ms/step - loss: -21645.4375 - accuracy: 0.3164 - val_loss: -10631.5869 - val_accuracy: 0.3281
# Epoch 50/100
# 26/26 [==============================] - 0s 4ms/step - loss: -26185.5039 - accuracy: 0.3125 - val_loss: -14583.4141 - val_accuracy: 0.3438
# Epoch 51/100
# 26/26 [==============================] - 0s 4ms/step - loss: -26236.9336 - accuracy: 0.3359 - val_loss: -17234.0781 - val_accuracy: 0.2812
# Epoch 52/100
# 26/26 [==============================] - 0s 4ms/step - loss: -34666.3516 - accuracy: 0.3164 - val_loss: -16584.7715 - val_accuracy: 0.2812
# Epoch 53/100
# 26/26 [==============================] - 0s 4ms/step - loss: -39942.8320 - accuracy: 0.3125 - val_loss: -22795.9277 - val_accuracy: 0.3281
# Epoch 54/100
# 26/26 [==============================] - 0s 4ms/step - loss: -50319.2188 - accuracy: 0.3320 - val_loss: -26983.8125 - val_accuracy: 0.2969
# Epoch 55/100
# 26/26 [==============================] - 0s 4ms/step - loss: -59053.7344 - accuracy: 0.3164 - val_loss: -35288.7227 - val_accuracy: 0.3438
# Epoch 56/100
# 26/26 [==============================] - 0s 3ms/step - loss: -67749.9766 - accuracy: 0.3281 - val_loss: -38155.7109 - val_accuracy: 0.3750
# Epoch 57/100
# 26/26 [==============================] - 0s 4ms/step - loss: -68083.7500 - accuracy: 0.3281 - val_loss: -47600.5469 - val_accuracy: 0.3906
# Epoch 58/100
# 26/26 [==============================] - 0s 3ms/step - loss: -91683.2891 - accuracy: 0.3203 - val_loss: -52321.4766 - val_accuracy: 0.3594
# Epoch 59/100
# 26/26 [==============================] - 0s 4ms/step - loss: -107162.5859 - accuracy: 0.3086 - val_loss: -65110.5938 - val_accuracy: 0.3438
# Epoch 60/100
# 26/26 [==============================] - 0s 4ms/step - loss: -123903.8125 - accuracy: 0.3164 - val_loss: -67967.7031 - val_accuracy: 0.3750
# Epoch 61/100
# 26/26 [==============================] - 0s 4ms/step - loss: -142201.7500 - accuracy: 0.3125 - val_loss: -74526.0625 - val_accuracy: 0.3594
# Epoch 62/100
# 26/26 [==============================] - 0s 3ms/step - loss: -169001.0156 - accuracy: 0.3672 - val_loss: -60845.5312 - val_accuracy: 0.2500
# Epoch 63/100
# 26/26 [==============================] - 0s 4ms/step - loss: -171989.9375 - accuracy: 0.3086 - val_loss: -95401.3672 - val_accuracy: 0.2969
# Epoch 64/100
# 26/26 [==============================] - 0s 4ms/step - loss: -212773.7812 - accuracy: 0.3242 - val_loss: -113779.7188 - val_accuracy: 0.3594
# Epoch 65/100
# 26/26 [==============================] - 0s 4ms/step - loss: -237661.5625 - accuracy: 0.3008 - val_loss: -127391.9219 - val_accuracy: 0.3906
# Epoch 66/100
# 26/26 [==============================] - 0s 4ms/step - loss: -255083.3906 - accuracy: 0.3359 - val_loss: -134494.4688 - val_accuracy: 0.3594
# Epoch 67/100
# 26/26 [==============================] - 0s 4ms/step - loss: -296187.0938 - accuracy: 0.3633 - val_loss: -139766.9844 - val_accuracy: 0.2812
# Epoch 68/100
# 26/26 [==============================] - 0s 3ms/step - loss: -318719.2500 - accuracy: 0.3203 - val_loss: -179656.9375 - val_accuracy: 0.3438
# Epoch 69/100
# 26/26 [==============================] - 0s 4ms/step - loss: -372483.4062 - accuracy: 0.3477 - val_loss: -158271.7188 - val_accuracy: 0.2656
# Epoch 70/100
# 26/26 [==============================] - 0s 4ms/step - loss: -381075.0938 - accuracy: 0.3047 - val_loss: -228217.2031 - val_accuracy: 0.3750
# Epoch 71/100
# 26/26 [==============================] - 0s 4ms/step - loss: -440272.8750 - accuracy: 0.3086 - val_loss: -251300.3750 - val_accuracy: 0.3594
# Epoch 72/100
# 26/26 [==============================] - 0s 4ms/step - loss: -465846.0000 - accuracy: 0.3125 - val_loss: -262860.7188 - val_accuracy: 0.3125
# Epoch 73/100
# 26/26 [==============================] - 0s 4ms/step - loss: -529794.4375 - accuracy: 0.3750 - val_loss: -265729.4062 - val_accuracy: 0.3281
# Epoch 74/100
# 26/26 [==============================] - 0s 4ms/step - loss: -581284.3750 - accuracy: 0.3164 - val_loss: -312681.4688 - val_accuracy: 0.3594
# Epoch 75/100
# 26/26 [==============================] - 0s 4ms/step - loss: -640288.4375 - accuracy: 0.3164 - val_loss: -344492.8125 - val_accuracy: 0.3438
# Epoch 76/100
# 26/26 [==============================] - 0s 4ms/step - loss: -669619.9375 - accuracy: 0.3008 - val_loss: -376698.6875 - val_accuracy: 0.3594
# Epoch 77/100
# 26/26 [==============================] - 0s 6ms/step - loss: -733679.3125 - accuracy: 0.3633 - val_loss: -395731.9375 - val_accuracy: 0.3438
# Epoch 78/100
# 26/26 [==============================] - 0s 6ms/step - loss: -774267.9375 - accuracy: 0.3477 - val_loss: -315960.9375 - val_accuracy: 0.2656
# Epoch 79/100
# 26/26 [==============================] - 0s 5ms/step - loss: -752411.6250 - accuracy: 0.3086 - val_loss: -484459.9688 - val_accuracy: 0.3750
# Epoch 80/100
# 26/26 [==============================] - 0s 6ms/step - loss: -949312.1875 - accuracy: 0.3359 - val_loss: -522677.5938 - val_accuracy: 0.3281
# Epoch 81/100
# 26/26 [==============================] - 0s 6ms/step - loss: -1003965.5625 - accuracy: 0.3047 - val_loss: -551270.1875 - val_accuracy: 0.3750
# Epoch 82/100
# 26/26 [==============================] - 0s 6ms/step - loss: -1061073.1250 - accuracy: 0.3438 - val_loss: -546736.6875 - val_accuracy: 0.3125
# Epoch 83/100
# 26/26 [==============================] - 0s 6ms/step - loss: -1069320.8750 - accuracy: 0.2969 - val_loss: -610722.8750 - val_accuracy: 0.3594
# Epoch 84/100
# 26/26 [==============================] - 0s 5ms/step - loss: -1235406.3750 - accuracy: 0.3438 - val_loss: -675980.0000 - val_accuracy: 0.3438
# Epoch 85/100
# 26/26 [==============================] - 0s 6ms/step - loss: -1342399.1250 - accuracy: 0.3320 - val_loss: -682548.5625 - val_accuracy: 0.3125
# Epoch 86/100
# 26/26 [==============================] - 0s 5ms/step - loss: -1431276.7500 - accuracy: 0.2812 - val_loss: -762921.3750 - val_accuracy: 0.3750
# Epoch 87/100
# 26/26 [==============================] - 0s 5ms/step - loss: -1485661.1250 - accuracy: 0.3672 - val_loss: -819159.1250 - val_accuracy: 0.3438
# Epoch 88/100
# 26/26 [==============================] - 0s 5ms/step - loss: -1634791.3750 - accuracy: 0.3203 - val_loss: -868258.9375 - val_accuracy: 0.3438
# Epoch 89/100
# 26/26 [==============================] - 0s 10ms/step - loss: -1663063.0000 - accuracy: 0.3047 - val_loss: -926481.3750 - val_accuracy: 0.3594
# Epoch 90/100
# 26/26 [==============================] - 0s 14ms/step - loss: -1857057.0000 - accuracy: 0.3594 - val_loss: -1001179.9375 - val_accuracy: 0.3281
# Epoch 91/100
# 26/26 [==============================] - 0s 11ms/step - loss: -1975195.5000 - accuracy: 0.3516 - val_loss: -959734.0625 - val_accuracy: 0.2969
# Epoch 92/100
# 26/26 [==============================] - 0s 14ms/step - loss: -1977914.0000 - accuracy: 0.3008 - val_loss: -1115173.2500 - val_accuracy: 0.3594
# Epoch 93/100
# 26/26 [==============================] - 0s 7ms/step - loss: -2260963.0000 - accuracy: 0.3359 - val_loss: -1172933.2500 - val_accuracy: 0.3281
# Epoch 94/100
# 26/26 [==============================] - 0s 4ms/step - loss: -2300102.2500 - accuracy: 0.3164 - val_loss: -1207118.5000 - val_accuracy: 0.3594
# Epoch 95/100
# 26/26 [==============================] - 0s 3ms/step - loss: -2476048.2500 - accuracy: 0.3164 - val_loss: -1321227.5000 - val_accuracy: 0.3594
# Epoch 96/100
# 26/26 [==============================] - 0s 4ms/step - loss: -2685047.2500 - accuracy: 0.3320 - val_loss: -1357633.2500 - val_accuracy: 0.3438
# Epoch 97/100
# 26/26 [==============================] - 0s 3ms/step - loss: -2701929.5000 - accuracy: 0.3398 - val_loss: -1555726.5000 - val_accuracy: 0.3438
# Epoch 98/100
# 26/26 [==============================] - 0s 3ms/step - loss: -3001626.5000 - accuracy: 0.3086 - val_loss: -1632179.7500 - val_accuracy: 0.3594
# Epoch 99/100
# 26/26 [==============================] - 0s 4ms/step - loss: -3193527.2500 - accuracy: 0.3242 - val_loss: -1672118.5000 - val_accuracy: 0.3438
# Epoch 100/100
# 26/26 [==============================] - 0s 4ms/step - loss: -3357104.0000 - accuracy: 0.3125 - val_loss: -1786769.0000 - val_accuracy: 0.3594

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=10,criterion='entropy')

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_predict = rfc.predict(x_test)

# %%
y_predict_train = rfc.predict(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth=4,splitter = 'best',criterion='entropy')

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_predict = dtc.predict(x_test)
y_predict
# Out:
# array([0, 0, 0, 0, 2, 0, 0, 0, 2, 0, 0, 0, 2, 2, 0, 0, 0, 2, 2, 0, 2, 2,
#        0, 2, 0, 2, 0, 0, 2, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 2, 0, 0, 0, 0,
#        0, 2, 0, 2, 2, 0, 0, 0, 0, 2, 0, 0, 0, 2, 2, 0, 0, 2, 2, 0, 0, 0,
#        0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 0, 0, 2, 0])

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()
lgr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,classification_report
y_predict = lgr.predict(x_test)

# %%
#logistic regression

y_pred = lgr.predict([[1,1,121.000000,36.0,0,0,1,0]])

print(y_pred)
(y_pred)
# Out:
# [2]
# array([2])

# %%
#decision tree classifier
y_pred = dtc.predict([[1,1,121.000000,36.0,0,0,1,0]])
print(y_pred)
(y_pred)
# Out:
# [2]
# array([2])

# %%
#randomforest classifier
y_pred = rfc.predict([[1,1,121.000000,36.0,0,0,1,0]])
print(y_pred)
(y_pred)
# Out:
# [2]
# array([2])

# %%
classification.save("ckd.h5")

# %% [markdown]
# y_pred = classification.predict(x_test)

# %%
y_pred
# Out:
# array([2])

# %%
y_pred = (y_pred >0.5)
y_pred
# Out:
# array([ True])

# %%
def predict_exit(sample_value):

  sample_value = np.array(sample_value)
  sample_value = sample_value.reshape(1,-1)
  sample_value = sc.transform(sample_value)
  return classification

# %%
test = classification.predict([[1,1,121.000000,36.0,0,0,1,0]])
if test==1:
  print('prediction: High chance of CKD!')
else:
  print('predication: LOW CHANCE OF CDK!')
# Out:
# 1/1 [==============================] - 0s 119ms/step
# prediction: High chance of CKD!

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix

# %%
from sklearn import model_selection

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dfs =[]
models = [
    ('LogReg',  LogisticRegression()),
    ('RF',RandomForestClassifier()),
    ('DecisionTree',DecisionTreeClassifier())
      ]

results = []
names = []
scoring = ['accuracy','precision_weighted','recall_weighted','f1_weighted','roc_auc']
target_names = ['NO CKD','','CKD',]
for name, model in models:
     kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=90210)
     cv_results = model_selection.cross_validate(model,x_train,y_train,cv = kfold,scoring=scoring)
     clf = model.fit(x_train,y_train)
     y_pred = clf.predict(x_test)
     print(name)
     print(classification_report(y_test,y_pred, target_names=target_names))
     results.append(cv_results)
     names.append(name)
     this_df =pd.DataFrame(cv_results)
     this_df['model'] = name
     dfs.append(this_df)
     final = pd.concat(dfs,ignore_index=True)
# Out:
# LogReg
#               precision    recall  f1-score   support
#
#       NO CKD       0.98      0.91      0.94        53
#                    0.00      0.00      0.00         1
#          CKD       0.84      1.00      0.91        26
#
#     accuracy                           0.93        80
#    macro avg       0.61      0.64      0.62        80
# weighted avg       0.92      0.93      0.92        80
#
# RF
#               precision    recall  f1-score   support
#
#       NO CKD       0.94      0.96      0.95        53
#                    0.00      0.00      0.00         1
#          CKD       0.92      0.92      0.92        26
#
#     accuracy                           0.94        80
#    macro avg       0.62      0.63      0.63        80
# weighted avg       0.93      0.94      0.93        80
#
# DecisionTree
#               precision    recall  f1-score   support
#
#       NO CKD       0.91      0.94      0.93        53
#                    0.00      0.00      0.00         1
#          CKD       0.88      0.85      0.86        26
#
#     accuracy                           0.90        80
#    macro avg       0.60      0.60      0.60        80
# weighted avg       0.89      0.90      0.89        80

# %%
from sklearn.metrics import  confusion_matrix
cm = confusion_matrix(y_test,y_predict)
cm
# Out:
# array([[48,  0,  5],
#        [ 1,  0,  0],
#        [ 0,  0, 26]])

# %%
plt.figure(figsize =(8,6))
sns.heatmap(cm, cmap = 'Blues', annot=True,xticklabels =['no_ckd','ckd'],yticklabels=['no ckd','ckd'])
plt.xlabel('predicted values')
plt.ylabel('actual values')
plt.title('Confusion Matrix for Logistic Regression Model')
plt.show()

# %%
data.to_csv('naan02.csv',index=False)

# %%
# Making the Confusion Matrix

from sklearn.metrics import  confusion_matrix
cm =confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[48,  0,  5],
#        [ 1,  0,  0],
#        [ 0,  0, 26]])

# %%
#plotting the confusion matrix
plt.figure(figsize =(8,6))
sns.heatmap(cm, cmap = 'Blues', annot=True,xticklabels =['no_ckd','ckd'],yticklabels=['no ckd','ckd'])
plt.xlabel('predicted values')
plt.ylabel('actual values')
plt.title('Confusion Matrix for RandomForestClassifier')
plt.show()

# %%
#Making the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[48,  0,  5],
#        [ 1,  0,  0],
#        [ 0,  0, 26]])

# %%
#plotting  confusion matrix
plt.figure(figsize =(8,6))
sns.heatmap(cm, cmap = 'Blues', annot=True,xticklabels =['no_ckd','ckd'],yticklabels=['no ckd','ckd'])
plt.xlabel('predicted values')
plt.ylabel('actual values')
plt.title('Confusion Matrix for DecisionTreeClassifier')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[50,  0,  3],
#        [ 1,  0,  0],
#        [ 4,  0, 22]])

# %%
#plotting confusion matrix
plt.figure(figsize =(8,6))
sns.heatmap(cm, cmap = 'Blues', annot=True,xticklabels =['no_ckd','ckd'],yticklabels=['no ckd','ckd'])
plt.xlabel('predicted values')
plt.ylabel('actual values')
plt.title('Confusion Matrix for ANN model')
plt.show()

# %%
from flask import Flask, render_template, request
import numpy as np
import pickle

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()

# %%
pickle.dump(lgr, open('CKD.pkl','wb'))
